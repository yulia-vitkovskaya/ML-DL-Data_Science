# %% [markdown]
# # Pandas часть 2. Домашнее Задание. Light
#
# *2 балла за каждую задачу*
#
# *1 бонусный балл, если все задачи покрыты комментариями, которые описывают тактику решение задачи (до 10 баллов)*

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('googleplaystore.csv')

# %% [markdown]
# ### Задача 1
#
# *2 балла*
#
# Загрузите базу статистики по приложениям из Google Play. Определите уникальные категории приложений. В цикле найдите число приложений по каждой категории.
#
# Описание базы:
# ---------------------------------
# **App** - имя приложения
#
# **Category** - категория
#
# **Rating** - рейтинг
#
# **Reviews** - число комментариев
#
# **Size** - размер
#
# **Instals** - число установок
#
# **Type** - платное или бесплатное приложение
#
# **Content Rating** - ограничения по возрасту
#
# **Genres** - жанры
#
# **Last Updated** - последнее обновление
#
# **Current Ver** - текущая версия
#
# **Android Ver** - версия для Android
#
#
# Ссылка на базу: https://drive.google.com/file/d/1dwFUK1PxzVLSyzHjPImCw_XvTIP-llJQ/view?usp=sharing

# %% [markdown]
# **Решение:**

# %%
unique_category = data.Category.unique().tolist()

# %%
for el in unique_category:
  print(f'{el} : {data[data.Category == el].shape[0]}')
# Out:
# ART_AND_DESIGN : 65
# AUTO_AND_VEHICLES : 85
# BEAUTY : 53
# BOOKS_AND_REFERENCE : 231
# BUSINESS : 460
# COMICS : 60
# COMMUNICATION : 387
# DATING : 234
# EDUCATION : 156
# ENTERTAINMENT : 149
# EVENTS : 64
# FINANCE : 366
# FOOD_AND_DRINK : 127
# HEALTH_AND_FITNESS : 341
# HOUSE_AND_HOME : 88
# LIBRARIES_AND_DEMO : 85
# LIFESTYLE : 382
# GAME : 1144
# FAMILY : 1972
# MEDICAL : 463
# SOCIAL : 295
# SHOPPING : 260
# PHOTOGRAPHY : 335
# SPORTS : 384
# TRAVEL_AND_LOCAL : 258
# TOOLS : 843
# PERSONALIZATION : 392
# PRODUCTIVITY : 424
# PARENTING : 60
# WEATHER : 82
# VIDEO_PLAYERS : 175
# NEWS_AND_MAGAZINES : 283
# MAPS_AND_NAVIGATION : 137
# 1.9 : 1

# %% [markdown]
# ### Задача 2
#
# *2 балла*
#
# Отсортируйте приложения по рейтингу при помощи встроенных методов Pandas.

# %% [markdown]
# **Решение:**

# %%
data2 = data.sort_values(by='Rating', ascending=False)
data2
# Out:
#                                            App             Category  Rating  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame                  1.9    19.0
# 9511                  Ek Bander Ne Kholi Dukan               FAMILY     5.0
# 10166                     FA Player Essentials               SPORTS     5.0
# 7895                Dine In CT - Food Delivery             SHOPPING     5.0
# 5118                          Eternal Light AG               SOCIAL     5.0
# ...                                        ...                  ...     ...
# 10824                                Cardio-FR              MEDICAL     NaN
# 10825                       Naruto & Boruto FR               SOCIAL     NaN
# 10831                 payermonstationnement.fr  MAPS_AND_NAVIGATION     NaN
# 10835                                 FR Forms             BUSINESS     NaN
# 10838                   Parkinson Exercices FR              MEDICAL     NaN
#
#       Reviews    Size Installs  Type     Price Content Rating  \
# 10472    3.0M  1,000+     Free     0  Everyone            NaN
# 9511       10    3.0M  10,000+  Free         0       Everyone
# 10166       7     68M     100+  Free         0       Everyone
# 7895        4    1.6M   1,000+  Free         0       Everyone
# 5118       30     13M     100+  Free         0           Teen
# ...       ...     ...      ...   ...       ...            ...
# 10824      67     82M  10,000+  Free         0       Everyone
# 10825       7    7.7M     100+  Free         0           Teen
# 10831      38    9.8M   5,000+  Free         0       Everyone
# 10835       0    9.6M      10+  Free         0       Everyone
# 10838       3    9.5M   1,000+  Free         0       Everyone
#
#                   Genres        Last Updated Current Ver   Android Ver
# 10472  February 11, 2018              1.0.19  4.0 and up           NaN
# 9511       Entertainment       June 26, 2017       1.0.9    4.0 and up
# 10166             Sports       July 23, 2018       1.6.0  4.0.3 and up
# 7895            Shopping        May 16, 2016         1.3    4.0 and up
# 5118              Social        May 19, 2018        1.04  4.0.3 and up
# ...                  ...                 ...         ...           ...
# 10824            Medical       July 31, 2018       2.2.2    4.4 and up
# 10825             Social    February 2, 2018         1.0    4.0 and up
# 10831  Maps & Navigation       June 13, 2018   2.0.148.0    4.0 and up
# 10835           Business  September 29, 2016       1.1.5    4.0 and up
# 10838            Medical    January 20, 2017         1.0    2.2 and up
#
# [10841 rows x 13 columns]

# %% [markdown]
# ### Задача 3
#
# *2 балла*
#
# Оставьте в выборке только те приложения, которые имеют рейтинг в пределах от 5 до 3 (оба значения включительно).
#
# Узнайте число платных и бесплатных приложений в этом списке при помощи методов Pandas.

# %% [markdown]
# **Решение:**

# %%
data2 = data2[(data2.Rating >= 3) & (data2.Rating <= 5)]
data2
# Out:
#                                                     App       Category  \
# 9511                           Ek Bander Ne Kholi Dukan         FAMILY
# 10166                              FA Player Essentials         SPORTS
# 7895                         Dine In CT - Food Delivery       SHOPPING
# 5118                                   Eternal Light AG         SOCIAL
# 6953                     BxPort - Bitcoin Bx (Thailand)        FINANCE
# ...                                                 ...            ...
# 6504                                        BN Mi Banco       BUSINESS
# 9950                          Emerge EV App (eBike App)      LIFESTYLE
# 915    Acorn TV: World-class TV from Britain and Beyond  ENTERTAINMENT
# 9933                            Qserve EU MDR First Aid       BUSINESS
# 5181    The Artificial Intelligence Project (A.I. Chat)         FAMILY
#
#        Rating Reviews                Size  Installs  Type  Price  \
# 9511      5.0      10                3.0M   10,000+  Free      0
# 10166     5.0       7                 68M      100+  Free      0
# 7895      5.0       4                1.6M    1,000+  Free      0
# 5118      5.0      30                 13M      100+  Free      0
# 6953      5.0       4                4.1M       50+  Free      0
# ...       ...     ...                 ...       ...   ...    ...
# 6504      3.0     597                 17M  100,000+  Free      0
# 9950      3.0      26  Varies with device    1,000+  Free      0
# 915       3.0     493                 23M   50,000+  Free      0
# 9933      3.0       2                 17M      100+  Free      0
# 5181      3.0      76                 39M    5,000+  Paid  $1.99
#
#       Content Rating         Genres    Last Updated         Current Ver  \
# 9511        Everyone  Entertainment   June 26, 2017               1.0.9
# 10166       Everyone         Sports   July 23, 2018               1.6.0
# 7895        Everyone       Shopping    May 16, 2016                 1.3
# 5118            Teen         Social    May 19, 2018                1.04
# 6953        Everyone        Finance   July 14, 2018               1.0.4
# ...              ...            ...             ...                 ...
# 6504        Everyone       Business   July 12, 2018                 9.0
# 9950        Everyone      Lifestyle    May 15, 2018  Varies with device
# 915         Everyone  Entertainment   June 15, 2018               2.0.0
# 9933        Everyone       Business    May 11, 2017              1.2.22
# 5181        Everyone     Simulation  March 29, 2018                 1.2
#
#         Android Ver
# 9511     4.0 and up
# 10166  4.0.3 and up
# 7895     4.0 and up
# 5118   4.0.3 and up
# 6953     4.2 and up
# ...             ...
# 6504     5.0 and up
# 9950     6.0 and up
# 915      4.4 and up
# 9933     4.1 and up
# 5181     2.3 and up
#
# [9079 rows x 13 columns]

# %%
print(f"Количество бесплатных : {data2[data2.Type == 'Free'].shape[0]}")
print(f"Количество платных : {data2[data2.Type == 'Paid'].shape[0]}")
# Out:
# Количество бесплатных : 8454
# Количество платных : 625

# %% [markdown]
# ### Задача 4
#
# *2 балла*

# %% [markdown]
# Обновите индексовый столбец датафрема, что бы индексовый столбец заполнился новыми числами (любыми).

# %% [markdown]
# **Решение:**

# %%
data2.index = [i for i in range(data2.shape[0])]
data2
# Out:
#                                                    App       Category  Rating  \
# 0                             Ek Bander Ne Kholi Dukan         FAMILY     5.0
# 1                                 FA Player Essentials         SPORTS     5.0
# 2                           Dine In CT - Food Delivery       SHOPPING     5.0
# 3                                     Eternal Light AG         SOCIAL     5.0
# 4                       BxPort - Bitcoin Bx (Thailand)        FINANCE     5.0
# ...                                                ...            ...     ...
# 9074                                       BN Mi Banco       BUSINESS     3.0
# 9075                         Emerge EV App (eBike App)      LIFESTYLE     3.0
# 9076  Acorn TV: World-class TV from Britain and Beyond  ENTERTAINMENT     3.0
# 9077                           Qserve EU MDR First Aid       BUSINESS     3.0
# 9078   The Artificial Intelligence Project (A.I. Chat)         FAMILY     3.0
#
#      Reviews                Size  Installs  Type  Price Content Rating  \
# 0         10                3.0M   10,000+  Free      0       Everyone
# 1          7                 68M      100+  Free      0       Everyone
# 2          4                1.6M    1,000+  Free      0       Everyone
# 3         30                 13M      100+  Free      0           Teen
# 4          4                4.1M       50+  Free      0       Everyone
# ...      ...                 ...       ...   ...    ...            ...
# 9074     597                 17M  100,000+  Free      0       Everyone
# 9075      26  Varies with device    1,000+  Free      0       Everyone
# 9076     493                 23M   50,000+  Free      0       Everyone
# 9077       2                 17M      100+  Free      0       Everyone
# 9078      76                 39M    5,000+  Paid  $1.99       Everyone
#
#              Genres    Last Updated         Current Ver   Android Ver
# 0     Entertainment   June 26, 2017               1.0.9    4.0 and up
# 1            Sports   July 23, 2018               1.6.0  4.0.3 and up
# 2          Shopping    May 16, 2016                 1.3    4.0 and up
# 3            Social    May 19, 2018                1.04  4.0.3 and up
# 4           Finance   July 14, 2018               1.0.4    4.2 and up
# ...             ...             ...                 ...           ...
# 9074       Business   July 12, 2018                 9.0    5.0 and up
# 9075      Lifestyle    May 15, 2018  Varies with device    6.0 and up
# 9076  Entertainment   June 15, 2018               2.0.0    4.4 and up
# 9077       Business    May 11, 2017              1.2.22    4.1 and up
# 9078     Simulation  March 29, 2018                 1.2    2.3 and up
#
# [9079 rows x 13 columns]

# %% [markdown]
# ### Задача 5
#
# *2 балла*

# %% [markdown]
# Определите процент пустых ячеек к заполненным в начальной таблице. Результат выведите в процентах с округлением до двух знаков.

# %% [markdown]
# **Решение:**

# %%
proc = data.isna().sum().sum() / data.size
print(round(100*proc, 2), '%')
# Out:
# 1.06 %
