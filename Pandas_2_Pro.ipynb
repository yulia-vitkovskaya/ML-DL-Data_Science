# %% [markdown]
# # Pandas часть 2. Домашнее Задание. Pro

# %%
import pandas as pd

# %%
data = pd.read_csv('data.csv', encoding = 'cp1250')

# %% [markdown]
# ### Задача 1. DateTime index
#
# * Подгрузите данные 'data.csv' (возможно, придется указать кодировку encoding cp1250) в переменную data.
# * Преобразуйте колонку InvoiceDate в DateTime index.
# * Удалите колонку InvoiceDate.

# %%
data.index = pd.to_datetime(data.InvoiceDate)
data.drop('InvoiceDate', axis = 1, inplace = True)

# %%
data
# Out:
#                     InvoiceNo StockCode                          Description  \
# InvoiceDate
# 2010-12-01 08:26:00    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 2010-12-01 08:26:00    536365     71053                  WHITE METAL LANTERN
# 2010-12-01 08:26:00    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 2010-12-01 08:26:00    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 2010-12-01 08:26:00    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...                       ...       ...                                  ...
# 2011-09-28 09:40:00    568576     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS
# 2011-09-28 09:40:00    568576     21915               RED  HARMONICA IN BOX
# 2011-09-28 09:40:00    568576     21914               BLUE HARMONICA IN BOX
# 2011-09-28 09:40:00    568576     22197                       POPCORN HOLDER
# NaT                    568576     21731                               RED TO
#
#                      Quantity  UnitPrice  CustomerID         Country
# InvoiceDate
# 2010-12-01 08:26:00       6.0       2.55     17850.0  United Kingdom
# 2010-12-01 08:26:00       6.0       3.39     17850.0  United Kingdom
# 2010-12-01 08:26:00       8.0       2.75     17850.0  United Kingdom
# 2010-12-01 08:26:00       6.0       3.39     17850.0  United Kingdom
# 2010-12-01 08:26:00       6.0       3.39     17850.0  United Kingdom
# ...                       ...        ...         ...             ...
# 2011-09-28 09:40:00      48.0       0.29     17017.0  United Kingdom
# 2011-09-28 09:40:00      24.0       1.25     17017.0  United Kingdom
# 2011-09-28 09:40:00      24.0       1.25     17017.0  United Kingdom
# 2011-09-28 09:40:00     100.0       0.72     17017.0  United Kingdom
# NaT                       NaN        NaN         NaN             NaN
#
# [363732 rows x 7 columns]

# %% [markdown]
# ### Задача 2
#
# Используя датафрейм data, выберите все заказы, совершенные за период 7 декабря 2010 года с часа дня до часа и одной минуты.

# %%
data['2010-12-07 13:00:00' : '2010-12-07 13:01:00']
# Out:
# <ipython-input-5-b3f51fcb995e>:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   data['2010-12-07 13:00:00' : '2010-12-07 13:01:00']
#                     InvoiceNo StockCode                          Description  \
# InvoiceDate
# 2010-12-07 13:01:00    537604     84991          60 TEATIME FAIRY CAKE CASES
# 2010-12-07 13:01:00    537604     21845                DAIRY MAID STRIPE MUG
# 2010-12-07 13:01:00    537604     21534            DAIRY MAID LARGE MILK JUG
# 2010-12-07 13:01:00    537604     21527    RED RETROSPOT TRADITIONAL TEAPOT
# 2010-12-07 13:01:00    537604     21528       DAIRY MAID TRADITIONAL TEAPOT
# 2010-12-07 13:01:00    537604     21843             RED RETROSPOT CAKE STAND
# 2010-12-07 13:01:00    537604     22429           ENAMEL MEASURING JUG CREAM
# 2010-12-07 13:01:00    537604     22551             PLASTERS IN TIN SPACEBOY
# 2010-12-07 13:01:00    537604     22557     PLASTERS IN TIN VINTAGE PAISLEY
# 2010-12-07 13:01:00    537604     22555            PLASTERS IN TIN STRONGMAN
# 2010-12-07 13:01:00    537604     22304       COFFEE MUG BLUE PAISLEY DESIGN
# 2010-12-07 13:01:00    537604     22305       COFFEE MUG PINK PAISLEY DESIGN
# 2010-12-07 13:01:00    537604     20749           ASSORTED COLOUR MINI CASES
# 2010-12-07 13:01:00    537604     22525         CHILDRENS GARDEN GLOVES PINK
# 2010-12-07 13:01:00    537604     22524         CHILDRENS GARDEN GLOVES BLUE
# 2010-12-07 13:01:00    537604     22515             CHILDS GARDEN SPADE PINK
# 2010-12-07 13:01:00    537604     22514             CHILDS GARDEN SPADE BLUE
# 2010-12-07 13:01:00    537604     22518             CHILDS GARDEN BRUSH BLUE
# 2010-12-07 13:01:00    537604     82552                  WASHROOM METAL SIGN
# 2010-12-07 13:01:00    537604     20750             RED RETROSPOT MINI CASES
# 2010-12-07 13:01:00    537604     21212      PACK OF 72 RETROSPOT CAKE CASES
# 2010-12-07 13:01:00    537604     21210   SET OF 72 RETROSPOT PAPER  DOILIES
13488.0  United Kingdom
# 2010-12-07 13:01:00      12.0       1.65     13488.0  United Kingdom
# 2010-12-07 13:01:00      12.0       1.65     13488.0  United Kingdom
# 2010-12-07 13:01:00      24.0       2.75     13488.0  United Kingdom
# 2010-12-07 13:01:00      32.0       2.55     13488.0  United Kingdom

# %% [markdown]
# ### Задача 3
#
#
# По той же рабочей табличке
# * посчитайте количество уникальных наименований товаров (Description), которые купили за весь период (т. е. по всем данным). Используйте соответствующий метод.
# * найдите все уникальные страны, в которых были размещены заказы.

# %%
data.Description.nunique()
# Out:
# 3935

# %%
data.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', nan], dtype=object)

# %% [markdown]
# ### Задача 4
#
#
# * Посчитайте матрицу корреляции Спирмена для наших данных.
# * Найдите 1%, 50% и 99% квантили цены за единицу товара.
#
# *Для решения данной задачи потребуется самостоятельно найти способ получения матрицы Спирмена. Обратите внимание, на вебинаре продемонстрирован пример матрицы Пирсона.*

# %%
data.corr(method='spearman')
# Out:
#             Quantity  UnitPrice  CustomerID
# Quantity    1.000000  -0.406294   -0.153087
# UnitPrice  -0.406294   1.000000   -0.003374
# CustomerID -0.153087  -0.003374    1.000000

# %%
data.groupby('UnitPrice').quantile(0.01)
# Out:
# <ipython-input-9-0a052d9f852b>:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.quantile is deprecated. In a future version, a TypeError will be raised. Before calling .quantile, select only columns which should be valid for the function.
#   data.groupby('UnitPrice').quantile(0.01)
#             Quantity  CustomerID
# UnitPrice
# -11062.060       1.0         NaN
#  0.000       -1440.0    12424.24
#  0.001           1.0    13421.41
#  0.010        -720.0    16422.00
#  0.030       -9177.6    12959.74
# ...              ...         ...
#  13474.790      -1.0         NaN
#  13541.330      -1.0         NaN
#  16453.710      -1.0         NaN
#  16888.020      -1.0         NaN
#  38970.000      -1.0    15098.00
#
# [1365 rows x 2 columns]

# %%
data.groupby('UnitPrice').quantile(0.5)
# Out:
# <ipython-input-15-f54dd8713cb9>:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.quantile is deprecated. In a future version, a TypeError will be raised. Before calling .quantile, select only columns which should be valid for the function.
#   data.groupby('UnitPrice').quantile(0.5)
#             Quantity  CustomerID
# UnitPrice
# -11062.060       1.0         NaN
#  0.000          -1.0     14646.0
#  0.001           1.0     14785.0
#  0.010        -720.0     16422.0
#  0.030        -240.0     15838.0
# ...              ...         ...
#  13474.790      -1.0         NaN
#  13541.330      -1.0         NaN
#  16453.710      -1.0         NaN
#  16888.020      -1.0         NaN
#  38970.000      -1.0     15098.0
#
# [1365 rows x 2 columns]

# %%
data.groupby('UnitPrice').quantile(0.99)
# Out:
# <ipython-input-16-d51e8fec58e1>:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.quantile is deprecated. In a future version, a TypeError will be raised. Before calling .quantile, select only columns which should be valid for the function.
#   data.groupby('UnitPrice').quantile(0.99)
#             Quantity  CustomerID
# UnitPrice
# -11062.060      1.00         NaN
#  0.000        374.24    17643.46
#  0.001          1.00    16180.60
#  0.010       -720.00    16422.00
#  0.030       -122.40    16410.32
# ...              ...         ...
#  13474.790     -1.00         NaN
#  13541.330      0.96         NaN
#  16453.710     -1.00         NaN
#  16888.020     -1.00         NaN
#  38970.000     -1.00    15098.00
#
# [1365 rows x 2 columns]

# %% [markdown]
# ### Задача 5
#
#
# Найдите количество клиентов, которые оформляли заказ в понедельники. Для этого
# * сделайте подвыборку, соответствующую условию "в понедельник",
# * посчитайте количество уникальных ID клиентов.
#
# *Для решения этой задачи потребуется использовать параметр индекса weekday (по аналогии с рассмотренными на вебинаре примерами .index.month, .index.day)*.

# %%
data.CustomerID[data.index.weekday == 0].nunique()
# Out:
# 1338
