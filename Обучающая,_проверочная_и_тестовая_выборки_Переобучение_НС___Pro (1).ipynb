# %% [markdown]
# #Задание

# %% [markdown]
# Используя модуль **datasets** библиотеки **sklearn**, загрузите базу вин (`.load_wine()`).
#
# Используя шаблон ноутбука, выполните загрузку, подготовку и предобработку данных. Обязательное условие: разделение данных на три выборки осуществляется по шаблону (изменять параметры подготовки данных запрещается)!
#
# Проведите серию экспериментов и добейтесь максимальной точности классификации на тестовой выборке выше 94%.
#
# ---
#
# С помощью метода `.summary()` зафиксируйте количество параметров созданной вами нейронной сети.

# %% [markdown]
# #Шаблон ноутбука

# %%
# Последовательная модель НС
from tensorflow.keras.models import Sequential

# Основные слои
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization

# Утилиты для to_categorical()
from tensorflow.keras import utils

# Алгоритмы оптимизации для обучения модели
from tensorflow.keras.optimizers import Adam

# Библиотека для работы с массивами
import numpy as np

# Отрисовка графиков
import matplotlib.pyplot as plt

# Разделение данных на выборки
from sklearn.model_selection import train_test_split

# Для загрузки датасета
from sklearn.datasets import load_wine

# Отрисовка изображений в ноутбуке, а не в консоли или файле
# %matplotlib inline

# %% [markdown]
# ##Описание базы
#
# 1. Датасет состоит из набора данных о винах и их классах.
# 2. Данные по одному вину хранятся в numpy-массиве `x_data`: (`13` параметров).
# 3. В датасете `3` класса вин: `y_data`.
# 4. Количество примеров: `178`.

# %%
x_data = load_wine()['data']              # Загрузка набора данных о винах
y_data = load_wine()['target']            # Загрузка классов вин

print('Размерность x_data -', x_data.shape)
print('Размерность y_data -', y_data.shape)
print()

# Вывод примера данных
print('Данные по первому вину:',x_data[0])
print('Класс вина:',y_data[0])
# Out:
# Размерность x_data - (178, 13)
# Размерность y_data - (178,)
#
# Данные по первому вину: [1.423e+01 1.710e+00 2.430e+00 1.560e+01 1.270e+02 2.800e+00 3.060e+00
#  2.800e-01 2.290e+00 5.640e+00 1.040e+00 3.920e+00 1.065e+03]
# Класс вина: 0

# %% [markdown]
# ##Подготовка данных

# %%
# Перевод в one hot encoding
y_data = utils.to_categorical(y_data, 3)

# Разбиение наборов на общую и тестовую выборки
x_all, x_test, y_all, y_test = train_test_split(x_data,
                                                y_data,
                                                test_size=0.1,
                                                shuffle=True,
                                                random_state = 6)

# Разбиение общей выборки на обучающую и проверочную
x_train, x_val, y_train, y_val = train_test_split(x_all,
                                                  y_all,
                                                  test_size=0.1,
                                                  shuffle=True,
                                                  random_state = 6)

print(x_train.shape)
print(y_train.shape)
print()
print(x_val.shape)
print(y_val.shape)
# Out:
# (144, 13)
# (144, 3)
#
# (16, 13)
# (16, 3)

# %%
# ваше решение
def model():
  model = Sequential()
  model.add(Dense(70, input_dim = 13, activation = 'relu'))
  model.add(Dropout(0.3))
  model.add(Dense(3, activation = 'softmax'))
  model.compile(loss="categorical_crossentropy",
                optimizer=Adam(learning_rate=0.001),
                metrics=["accuracy"])
  model.fit(x_train,
            y_train,
            batch_size=32,
            epochs=150,
            verbose=1,
            validation_data=(x_val, y_val),
            shuffle=True)
  scores = model.evaluate(x_test, y_test, verbose=1)
  print('Доля верных ответов на тестовых данных, в процентах: {:7.4%}'.format(scores[1]))
  model.summary()

150
# 5/5 [==============================] - 0s 10ms/step - loss: 1.5991 - accuracy: 0.7847 - val_loss: 0.2533 - val_accuracy: 0.8750
# Epoch 119/150
# 5/5 [==============================] - 0s 14ms/step - loss: 2.2794 - accuracy: 0.6875 - val_loss: 0.2178 - val_accuracy: 0.9375
# Epoch 120/150
# 5/5 [==============================] - 0s 12ms/step - loss: 2.0000 - accuracy: 0.7083 - val_loss: 0.1886 - val_accuracy: 0.9375
# Epoch 121/150
# 5/5 [==============================] - 0s 10ms/step - loss: 1.7357 - accuracy: 0.7500 - val_loss: 0.1915 - val_accuracy: 0.8750
# Epoch 122/150
# 5/5 [==============================] - 0s 10ms/step - loss: 1.6668 - accuracy: 0.7292 - val_loss: 0.1564 - val_accuracy: 0.8750
# Epoch 123/150
# 5/5 [==============================] - 0s 10ms/step - loss: 1.6539 - accuracy: 0.6944 - val_loss: 0.1396 - val_accuracy: 0.9375
# Epoch 124/150
# 5/5 [==============================] - 0s 10ms/step - loss: 1.7212 - accuracy: 0.7083 - val_loss: 0.1854 - val_accuracy: 0.8750
# Epoch 125/150
# 5/5 [==============================] - 0s 10ms/step - loss: 1.5907 - accuracy: 0.7361 - val_loss: 0.1764 - val_accuracy: 0.9375
# Epoch 126/150
# 5/5 [==============================] - 0s 12ms/step - loss: 1.7098 - accuracy: 0.7222 - val_loss: 0.1774 - val_accuracy: 0.8750
# Epoch 127/150
# 5/5 [==============================] - 0s 11ms/step - loss: 1.6439 - accuracy: 0.7431 - val_loss: 0.1214 - val_accuracy: 0.9375
# Epoch 128/150
# 5/5 [==============================] - 0s 10ms/step - loss: 1.6285 - accuracy: 0.7431 - val_loss: 0.1386 - val_accuracy: 0.9375
# Epoch 129/150
# 5/5 [==============================] - 0s 10ms/step - loss: 1.1522 - accuracy: 0.7708 - val_loss: 0.1287 - val_accuracy: 0.9375
# Epoch 130/150
# 5/5 [==============================] - 0s 11ms/step - loss: 1.3285 - accuracy: 0.7361 - val_loss: 0.1237 - val_accuracy: 0.9375
# Epoch 131/150
# 5/5 [==============================] - 0s 13ms/step - loss: 1.3120 - accuracy: 0.7639 - val_loss: 0.1345 - val_accuracy: 0.9375
# Epoch 132/150
# 5/5 [==============================] - 0s 10ms/step - loss: 1.1839 - accuracy: 0.7639 - val_loss: 0.1048 - val_accuracy: 1.0000
# Epoch 133/150
# 5/5 [==============================] - 0s 10ms/step - loss: 1.3189 - accuracy: 0.7500 - val_loss: 0.0913 - val_accuracy: 1.0000
# Epoch 134/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8526 - accuracy: 0.8472 - val_loss: 0.1036 - val_accuracy: 1.0000
# Epoch 135/150
# 5/5 [==============================] - 0s 10ms/step - loss: 1.1906 - accuracy: 0.7639 - val_loss: 0.1215 - val_accuracy: 0.9375
# Epoch 136/150
# 5/5 [==============================] - 0s 10ms/step - loss: 1.2030 - accuracy: 0.7708 - val_loss: 0.1522 - val_accuracy: 0.9375
# Epoch 137/150
# 5/5 [==============================] - 0s 11ms/step - loss: 1.0986 - accuracy: 0.7569 - val_loss: 0.1107 - val_accuracy: 1.0000
# Epoch 138/150
# 5/5 [==============================] - 0s 11ms/step - loss: 0.9178 - accuracy: 0.7986 - val_loss: 0.0839 - val_accuracy: 1.0000
# Epoch 139/150
# 5/5 [==============================] - 0s 10ms/step - loss: 1.1739 - accuracy: 0.7431 - val_loss: 0.0897 - val_accuracy: 1.0000
# Epoch 140/150
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7961 - accuracy: 0.7986 - val_loss: 0.0979 - val_accuracy: 1.0000
# Epoch 141/150
# 5/5 [==============================] - 0s 10ms/step - loss: 1.0020 - accuracy: 0.7778 - val_loss: 0.0901 - val_accuracy: 1.0000
# Epoch 142/150
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8477 - accuracy: 0.8194 - val_loss: 0.1151 - val_accuracy: 0.9375
# Epoch 143/150
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8920 - accuracy: 0.7847 - val_loss: 0.0994 - val_accuracy: 1.0000
# Epoch 144/150
# 5/5 [==============================] - 0s 11ms/step - loss: 1.0633 - accuracy: 0.7014 - val_loss: 0.1052 - val_accuracy: 1.0000
# Epoch 145/150
# 5/5 [==============================] - 0s 11ms/step - loss: 0.7504 - accuracy: 0.8333 - val_loss: 0.1019 - val_accuracy: 0.9375
# Epoch 146/150
# 5/5 [==============================] - 0s 10ms/step - loss: 0.8862 - accuracy: 0.7917 - val_loss: 0.1082 - val_accuracy: 1.0000
# Epoch 147/150
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5843 - accuracy: 0.7778 - val_loss: 0.1095 - val_accuracy: 1.0000
# Epoch 148/150
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5446 - accuracy: 0.7986 - val_loss: 0.1184 - val_accuracy: 0.9375
# Epoch 149/150
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7600 - accuracy: 0.7708 - val_loss: 0.1229 - val_accuracy: 1.0000
# Epoch 150/150
# 5/5 [==============================] - 0s 11ms/step - loss: 0.6035 - accuracy: 0.8194 - val_loss: 0.1192 - val_accuracy: 1.0000
# 1/1 [==============================] - 0s 25ms/step - loss: 0.4177 - accuracy: 0.9444
# Доля верных ответов на тестовых данных, в процентах: 94.4444%
# Model: "sequential_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_70 (Dense)            (None, 70)                980
#
#  dropout_29 (Dropout)        (None, 70)                0
#
#  dense_71 (Dense)            (None, 3)                 213
#
# =================================================================
# Total params: 1,193
# Trainable params: 1,193
# Non-trainable params: 0
# _________________________________________________________________
